# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('movies_data.csv')
data.head()
# Out:
#          id    imdb_id  popularity       budget       revenue  \
# 0  135397.0  tt0369610   32.985763  150000000.0  1.513529e+09
# 1   76341.0  tt1392190   28.419936  150000000.0  3.784364e+08
# 2  262500.0  tt2908446   13.112507  110000000.0  2.952382e+08
# 3  257344.0  tt2120120    5.984995   88000000.0  2.436371e+08
# 4  168259.0  tt2820852    9.335014  190000000.0  1.506249e+09
#
#        original_title                                               cast  \
# 0      Jurassic World  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Mad Max: Fury Road  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2           Insurgent  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3              Pixels  Adam Sandler|Michelle Monaghan|Peter Dinklage|...
# 4           Furious 7  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# ...

# %%
data.shape
# Out:
# (10866, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1000 non-null   float64
#  1   imdb_id               998 non-null    object
#  2   popularity            1000 non-null   float64
#  3   budget                997 non-null    float64
#  4   revenue               1000 non-null   float64
#  5   original_title        1000 non-null   object
#  6   cast                  992 non-null    object
#  7   homepage              397 non-null    object
#  8   director              997 non-null    object
#  9   tagline               731 non-null    object
#  10  keywords              805 non-null    object
#  11  overview              999 non-null    object
#  12  runtime               1000 non-null   float64
#  13  genres                997 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# id                       9866
# imdb_id                  9868
# popularity               9866
# budget                   9869
# revenue                  9866
# original_title           9866
# cast                     9874
# homepage                10469
# director                 9869
# tagline                 10135
# keywords                10061
# overview                 9867
# runtime                  9866
# genres                   9869
# production_companies     9936
# release_date             9866
# vote_count               9870
# vote_average             9868
# release_year             9866
# budget_adj               9867
# revenue_adj              9868
# dtype: int64

# %%
per_missing=data.isnull().sum()*100/len(data)
per_missing
# Out:
# id                      90.796981
# imdb_id                 90.815387
# popularity              90.796981
# budget                  90.824590
# revenue                 90.796981
# original_title          90.796981
# cast                    90.870606
# homepage                96.346402
# director                90.824590
# tagline                 93.272593
# keywords                92.591570
# overview                90.806184
# runtime                 90.796981
# genres                  90.824590
# production_companies    91.441193
# release_date            90.796981
# vote_count              90.833793
# vote_average            90.815387
# release_year            90.796981
# budget_adj              90.806184
# revenue_adj             90.815387
# dtype: float64

# %%
data.dropna(axis=0)
# Out:
#            id    imdb_id  popularity       budget       revenue  \
# 0    135397.0  tt0369610   32.985763  150000000.0  1.513529e+09
# 1     76341.0  tt1392190   28.419936  150000000.0  3.784364e+08
# 2    262500.0  tt2908446   13.112507  110000000.0  2.952382e+08
# 3    257344.0  tt2120120    5.984995   88000000.0  2.436371e+08
# 5    281957.0  tt1663202    9.110700  135000000.0  5.329505e+08
# ..        ...        ...         ...          ...           ...
# 975  238475.0  tt2499414    0.351449          0.0  0.000000e+00
# 976  284536.0  tt2039393    0.350612   25000000.0  3.917113e+07
# 990  254194.0  tt2793490    0.539598          0.0  0.000000e+00
# 993   82657.0  tt1975159    0.332041          0.0  0.000000e+00
# 996   94590.0  tt2123146    0.330541     325927.0  0.000000e+00
#
#                        original_title  \
# 0                      Jurassic World
# 1                  Mad Max: Fury Road
# 2                           Insurgent
# 3                              Pixels
# ...

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10861     True
# 10862     True
# 10863     True
# 10864     True
# 10865     True
# Length: 10866, dtype: bool

# %%
data=data.drop_duplicates()
data
# Out:
#             id    imdb_id  popularity       budget       revenue  \
# 0     135397.0  tt0369610   32.985763  150000000.0  1.513529e+09
# 1      76341.0  tt1392190   28.419936  150000000.0  3.784364e+08
# 2     262500.0  tt2908446   13.112507  110000000.0  2.952382e+08
# 3     257344.0  tt2120120    5.984995   88000000.0  2.436371e+08
# 4     168259.0  tt2820852    9.335014  190000000.0  1.506249e+09
# ...        ...        ...         ...          ...           ...
# 996    94590.0  tt2123146    0.330541     325927.0  0.000000e+00
# 997   287663.0        NaN    0.330431          0.0  0.000000e+00
# 998   199575.0  tt2268458    0.276845          0.0  0.000000e+00
# 999   174337.0  tt2140577    0.460808          0.0  1.376900e+04
# 1000       NaN        NaN         NaN          NaN           NaN
#
#                             original_title  \
# 0                           Jurassic World
# 1                       Mad Max: Fury Road
# 2                                Insurgent
# ...

# %%
data.describe()
# Out:
#                   id  popularity        budget       revenue     runtime  \
# count     996.000000  996.000000  9.930000e+02  9.960000e+02  996.000000
# mean   269570.828313    1.195193  1.495568e+07  4.883623e+07   98.456827
# std     68586.948878    2.219451  3.629711e+07  1.492095e+08   23.879916
# min       189.000000    0.003920  0.000000e+00  0.000000e+00    0.000000
# 25%    239651.750000    0.299953  0.000000e+00  0.000000e+00   89.000000
# 50%    280391.000000    0.533023  0.000000e+00  0.000000e+00   97.000000
# 75%    322471.500000    1.212230  1.100000e+07  1.467924e+07  109.000000
# max    395883.000000   32.985763  2.800000e+08  1.513529e+09  300.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count   992.000000    994.000000    996.000000  9.950000e+02  9.940000e+02
# mean    367.098790      5.918612   2014.627510  1.376306e+07  4.474473e+07
# std     767.633532      1.051679      0.483711  3.339911e+07  1.372305e+08
# ...

# %%
data.describe(include='all')
# Out:
#                    id    imdb_id  popularity        budget       revenue  \
# count      996.000000        994  996.000000  9.930000e+02  9.960000e+02
# unique            NaN        994         NaN           NaN           NaN
# top               NaN  tt4941804         NaN           NaN           NaN
# freq              NaN          1         NaN           NaN           NaN
# mean    269570.828313        NaN    1.195193  1.495568e+07  4.883623e+07
# std      68586.948878        NaN    2.219451  3.629711e+07  1.492095e+08
# min        189.000000        NaN    0.003920  0.000000e+00  0.000000e+00
# 25%     239651.750000        NaN    0.299953  0.000000e+00  0.000000e+00
# 50%     280391.000000        NaN    0.533023  0.000000e+00  0.000000e+00
# 75%     322471.500000        NaN    1.212230  1.100000e+07  1.467924e+07
# max     395883.000000        NaN   32.985763  2.800000e+08  1.513529e+09
#
#                  original_title  \
# count                       996
# ...

# %% [markdown]
# ### Display title of the moving having runtime>=180

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data[data['runtime']>=180]['original_title']
# Out:
# 415                                   Show Me a Hero
# 559                                  Childhood's End
# 609    The Jinx: The Life and Deaths of Robert Durst
# 989                                 Olive Kitteridge
# Name: original_title, dtype: object

# %% [markdown]
# ### inwhich year there was the highest average voting

# %%
data.groupby('release_year')['vote_average'].mean()
# Out:
# release_year
# 2014.0    5.986792
# 2015.0    5.878010
# Name: vote_average, dtype: float64

# %%
labels=['2014','2015']
values=[5.986792,5.878010]
plt.bar(labels,values)
plt.title('votes by year')
plt.xlabel('year')
plt.ylabel('vote')
plt.show()

# %% [markdown]
# ### inwhich year there was the highest average revenue

# %%
data.groupby('release_year')['revenue'].mean()
# Out:
# release_year
# 2014.0    6.525108e+07
# 2015.0    3.909238e+07
# Name: revenue, dtype: float64

# %%
labels=['2014','2015']
values=[6.525108e+07,3.909238e+07]
plt.bar(labels,values)
plt.title('revenue by year')
plt.xlabel('year')
plt.ylabel('revenue')
plt.show()

# %% [markdown]
# ### Display Top 10 Lengthy Movies Title and Runtime

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
Top10=data.nlargest(10,'runtime')[['original_title','runtime']].set_index('original_title')
Top10
# Out:
#                                                runtime
# original_title
# Show Me a Hero                                   300.0
# Childhood's End                                  246.0
# The Jinx: The Life and Deaths of Robert Durst    240.0
# Olive Kitteridge                                 233.0
# Interstellar                                     169.0
# And Then There Were None                         168.0
# The Hateful Eight                                167.0
# Transformers: Age of Extinction                  165.0
# Boyhood                                          164.0
# The Revenant                                     156.0

# %%
sns.barplot(x='runtime',y=Top10.index ,data=Top10)
plt.title('The top10 movies by runtime')
plt.show()

# %% [markdown]
# ### Display Number of Movies Per Year

# %%
data['release_year'].value_counts()
# Out:
# 2015.0    625
# 2014.0    371
# Name: release_year, dtype: int64

# %%
sns.countplot(x='release_year' ,data=data)
plt.title('Number of movies by year')
plt.show()

# %% [markdown]
# ### Find Most Popular Movie Title Highest Revenue

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data[data['revenue'].max()==data['revenue']]['original_title']
# Out:
# 0    Jurassic World
# Name: original_title, dtype: object

# %% [markdown]
# ###  Display Top 10 Highest Revenue Movie Titles

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
top10=data.nlargest(10,'revenue')[['original_title','revenue']].set_index('original_title')
top10
# Out:
#                                                 revenue
# original_title
# Jurassic World                             1.513529e+09
# Furious 7                                  1.506249e+09
# Avengers: Age of Ultron                    1.405036e+09
# Minions                                    1.156731e+09
# The Hobbit: The Battle of the Five Armies  9.551198e+08
# Spectre                                    8.806746e+08
# Inside Out                                 8.537086e+08
# Guardians of the Galaxy                    7.733124e+08
# Maleficent                                 7.584104e+08
# The Hunger Games: Mockingjay - Part 1      7.521002e+08

# %%
sns.barplot(x='revenue',y=top10.index ,data=top10)
plt.title('The top10 movies by revenue')
plt.show()
